# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Default plot configurations
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

import warnings
warnings.filterwarnings("ignore")

from IPython.display import display, Latex, Markdown

# get data from csv
pancake = pd.read_csv('pancake.csv')
pancake
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e80643cb98f2> in <module>
#      16
#      17 # get data from csv
# ---> 18 pancake = pd.read_csv('pancake.csv')
#      19 pancake
#
# /usr/local/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
# outlier detection
label = "TxnFee(ETH)"
for _ in range(8):
    sushiswap = sushiswap.loc[sushiswap[label] != sushiswap[label].max()]
sushiswap.sort_values(label, ascending=False)
# Out:
#                                                       Txhash     Blockno  \
# 0x4befcffb33da0a9c0c7b0915fd890224bd34e105bdf85...  13718577  1638327204
# 0x09a813eda7242594ed16b78cf7d6e90d908d62736facb...  13718779  1638330106
# 0xd892c047bf69538f7441dc1652e59c2a642b1e2b78a82...  13718780  1638330141
# 0x76cb346a8b8acdcbce04fca5ef9e9227be3c64e234589...  13720154  1638349513
# 0x1326ac5f417cf44dd3a98207302f38400cef092452faf...  13718766  1638329873
# ...                                                      ...         ...
# 0xe6f66e45b73ab634918bafcc0bf82cc5b3861166f6c6c...  13718213  1638321985
# 0x774185f150a99810477157de7dcbb35eb03ed9fc99c93...  13720560  1638355001
# 0x62efe03685ac320fb34a2838fc725342e669b59d27185...  13720820  1638358505
# 0xc43eba1d833d283d6f5876e685b02cce76fc324bab25f...  13720820  1638358505
# 0x855f2de4f9a18a267d6df72ce5a0060bd5fcddac4633c...  13720592  1638355348
#
#                                                           UnixTimestamp  \
# ...

# %%
label = "TxnFee(ETH)"
cd_label = f"curvedata {label}"
tbl = curvedata.rename({label:cd_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=cd_label)

us_label = f"uniswap {label}"
tbl = uniswap.rename({label:us_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=us_label)

ss_label = f"sushiswap {label}"
tbl = sushiswap.rename({label:ss_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=ss_label)

plt.legend(loc='upper left')
x = "DateTime"
plt.xlabel(x)
plt.ylabel(label)
plt.title(f"{label} vs {x}");

# %%
filename = 'data.txt'
data = open(filename).read().splitlines()
# print(data)
n = 1000
assert n == len(data), "error reading all data"
split_point = n >> 1
spent, received = np.array(data[::2]), np.array(data[1::2])
print(spent, received, sep="\n"*3)
spent, received = spent.astype(np.float), received.astype(np.float)
total_ETH_spent = spent/1e18
received = received/1e8
spent **= 2
# print(total_ETH_spent, received,sep='\n'*3)
# Out:
# ['10000000000000000' '20240000000000000' '30725760000000000'
#  '41463178240000000' '52458294517760000' '63717293586186240'
#  '75246508632254709' '87052424839428821' '99141683035575111'
#  '111521083428428911' '124197589430711202' '137178331577048267'
#  '150470611534897421' '164081906211734954' '178019871960816587'
#  '192292348887876179' '206907365261185201' '221873142027453639'
#  '237198097436112519' '252890851774579212' '268960232217169105'
#  '285415277790381155' '302265244457350294' '319519610324326692'
#  '337188080972110523' '355280594915441165' '373807329193411742'
#  '392778705094053612' '412205394016310886' '432098323472702334'
#  '452468683236047176' '473327931633712294' '494687801992921374'
#  '516560309240751471' '538957756662529490' '561892742822430181'
#  '585378168650168488' '609427244697772514' '634053498570519036'
#  '659270782536211474' '685093281317080530' '711535520068690443'
#  '738612372550338993' '766339069491547108' '794731207159344217'
# ...

# %%
print(total_ETH_spent, received,sep='\n'*3)
# Out:
# [1.00000000e-02 2.02400000e-02 3.07257600e-02 4.14631782e-02
#  5.24582945e-02 6.37172936e-02 7.52465086e-02 8.70524248e-02
#  9.91416830e-02 1.11521083e-01 1.24197589e-01 1.37178332e-01
#  1.50470612e-01 1.64081906e-01 1.78019872e-01 1.92292349e-01
#  2.06907365e-01 2.21873142e-01 2.37198097e-01 2.52890852e-01
#  2.68960232e-01 2.85415278e-01 3.02265244e-01 3.19519610e-01
#  3.37188081e-01 3.55280595e-01 3.73807329e-01 3.92778705e-01
#  4.12205394e-01 4.32098323e-01 4.52468683e-01 4.73327932e-01
#  4.94687802e-01 5.16560309e-01 5.38957757e-01 5.61892743e-01
#  5.85378169e-01 6.09427245e-01 6.34053499e-01 6.59270783e-01
#  6.85093281e-01 7.11535520e-01 7.38612373e-01 7.66339069e-01
#  7.94731207e-01 8.23804756e-01 8.53576070e-01 8.84061896e-01
#  9.15279381e-01 9.47246087e-01 9.79979993e-01 1.01349951e+00
#  1.04782350e+00 1.08297126e+00 1.11896258e+00 1.15581768e+00
#  1.19355730e+00 1.23220268e+00 1.27177554e+00 1.31229815e+00
# ...

# %%
sns.lineplot(total_ETH_spent, received)
x, y = "Total ETH Spent", "Received"
plt.xlabel(x)
plt.ylabel(y)
plt.title(f"{y} vs {x}");

# %%
x, y = received, total_ETH_spent/received
sns.lineplot(x, y)
xl, yl = "Quantity of BTC bought", "Price (ETH/BTC)"
plt.xlabel(xl)
plt.ylabel(yl)
plt.ylim(8, 20)
plt.title(f"{yl} vs {xl}");

# %%
# derivative
from scipy.misc import derivative

plt.plot(x, np.gradient(y, x), 'b')
plt.show()
