# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', 50)

# Default plot configurations
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

import warnings
warnings.filterwarnings("ignore")

from IPython.display import display, Latex, Markdown

# get data from csv
pancakeswap = pd.read_csv('pancakeswap.csv', index_col=False)
pancakeswap
# Out:
#                                                  Txhash   Blockno  \
# 0     0x1dd32d3ebb1f4ae0a228f4df55ac1415c8486283e4d2...  13089738
# 1     0xd787bf9c17e2dcb718fbce1aed20873506617c8663fc...  13089738
# 2     0x045d3ba5dc0fa3a4d171143758183211f49b9f5c4a1f...  13089738
# 3     0x0ed35921abcf228b63ebd769c86ba6f9191271606cec...  13089738
# 4     0x3688c3e7e173de95920dbeb4f38df39e6cb9a5abee53...  13089738
# ...                                                 ...       ...
# 4995  0xb7926a36a6a88964e4195b2d84b807df3e62258b7b08...  13089846
# 4996  0xce575e0692373dc30bcb9981f850e7d46944bad67919...  13089846
# 4997  0x6a46339cf808dfc7809bbdc8c7a24f96fb94d22204eb...  13089846
# 4998  0x68684dabf3d826b645fbc4b6c910806835dab2d07be6...  13089846
# 4999  0xfe6c8a42969ee15b3ee1c1bb3cf4bf1b273406b3d7f0...  13089846
#
#       UnixTimestamp             DateTime  \
# 0        1638316800  2021-12-01 00:00:00
# 1        1638316800  2021-12-01 00:00:00
# 2        1638316800  2021-12-01 00:00:00
# ...

# %%
label = "TxnFee(USD)"
pancakeswap.sort_values(label, ascending=True)
# Out:
#                                                  Txhash   Blockno  \
# 4632  0x746ca360ed65db4ffb127750c8b37cadee88b97e4830...  13089835
# 3626  0x88e09c7bb8a8ae1342d25024ec6b47266080bc42316c...  13089813
# 3660  0x26f12a3ee9521f046c1f13183f517eb8429f28e52872...  13089814
# 3667  0x10b0fddeba2b25f4579b985a599280cc885e2fc8cc80...  13089814
# 2576  0xe3b5d20189912d735afe40e198eff737f61d6f16e277...  13089789
# ...                                                 ...       ...
# 3942  0xb89e1a1550f3c11e1993698ac2eddbd58c2b2359c4d6...  13089821
# 682   0xad092da8b39d0ac0d266ab49c38fe187cd7b480c51d2...  13089746
# 3759  0x68a64fbc29ad637ce9ba89dd90c3a453b15f987995a6...  13089817
# 1350  0xbcb498bdaac0bd8c74eb37b5f31c430028b79221c660...  13089759
# 4209  0x714d5453c0db51960b4f2839d40535c1b51fb882aa7e...  13089826
#
#       UnixTimestamp             DateTime  \
# 4632     1638317114  2021-12-01 00:05:14
# 3626     1638317040  2021-12-01 00:04:00
# 3660     1638317043  2021-12-01 00:04:03
# ...

# %%
# # outlier detection
# label = "TxnFee(BNB)"
# for _ in range(8):
#     sushiswap = sushiswap.loc[sushiswap[label] != sushiswap[label].max()]
# pancake.sort_values(label, ascending=False)

# %%
label = "TxnFee(USD)"
tbl = pancakeswap
ax = sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=label)
ax.set(xticklabels=[])
plt.legend(loc='upper left')
x = "DateTime"
plt.xlabel(x)
plt.ylabel(label)
plt.title(f"{label} vs {x}");

# %%
label = "TxnFee(USD)"
series = pancakeswap[label]
series
# Out:
# 0       1.105343
# 1       0.795992
# 2       0.586351
# 3       0.437554
# 4       0.707058
#           ...
# 4995    2.406103
# 4996    0.688739
# 4997    0.895273
# 4998    0.802339
# 4999    0.439209
# Name: TxnFee(USD), Length: 5000, dtype: float64

# %%
ax = sns.kdeplot(data=pancakeswap, y="TxnFee(USD)", shade=True, vertical=True)
ax.set(xlim=(0, 3))
plt.title("PancakeSwap: Kernel Density Estimate Plot");

# %%
uniswap = pd.read_csv('uniswap.csv', index_col=False)
uniswap
# Out:
#                                                  Txhash   Blockno  \
# 0     0xa761f3c7cd9d32325ca2d2ce8682a70f3bba939cbfcc...  13717847
# 1     0x522ca51c4e1ab6a62a374646618597935187a79ce44c...  13717847
# 2     0x548160f1141f451a065b6f98d4db5ed6f8fb23d918fe...  13717847
# 3     0x0a04b38bf7bfb7ad4fa44a1460e718c1039a58798462...  13717847
# 4     0x4a4018e74f77af78c9320cbbc02ed804d30638f16c33...  13717847
# ...                                                 ...       ...
# 4995  0x959e3538b1f6ac3b68bd5ae862e97915b36ad41a36f3...  13719430
# 4996  0x2af717f2488023a66777afbdd567ef6da2e1c1d4148d...  13719430
# 4997  0xf286731baa778fc67ffef73235d32827a4ebf3f007de...  13719430
# 4998  0x745ffe95a0956c5b39d89347c343860fcbc5c76e9441...  13719430
# 4999  0x96cb40f5861a561f773d78bfe314cfbf67a398839d01...  13719430
#
#       UnixTimestamp             DateTime  \
# 0        1638316845  2021-12-01 00:00:45
# 1        1638316845  2021-12-01 00:00:45
# 2        1638316845  2021-12-01 00:00:45
# ...

# %%
ax = sns.kdeplot(data=uniswap, y="TxnFee(USD)", shade=True, vertical=True)
ax.set(xlim=(0, 200))
plt.title("Uniswap V3: Kernel Density Estimate Plot");

# %%
sushiswap = pd.read_csv('sushiswap.csv', index_col=False)
sushiswap
# Out:
#                                                  Txhash   Blockno  \
# 0     0xee18f6342683fdf60bbb57abc1f00e607ed034427a72...  13717847
# 1     0x51677a40b48456b15cce7e399c69d169c7a032beb951...  13717847
# 2     0xff0d2e021d59bb7d471ee3e3ecddd5ef679c4b7433f0...  13717849
# 3     0x0844b05ef2d68f509e495d2564ecba8f9eec1c7feb03...  13717849
# 4     0xd086dc6c6990016b8bfbb2959bade7c4b15e1feaf547...  13717849
# ...                                                 ...       ...
# 4995  0xf560b03021ab34c9a6b58cf059cf2a1c1dc8c8599f73...  13722350
# 4996  0xdd188fab54b97a6777ead3af9a084fd4e4dd1cbb167f...  13722351
# 4997  0x21cb9f6a22f585dcaf506997367b409c4025e34b30e5...  13722352
# 4998  0xf2246d0a9fac22b184e9cc2678facdc069e24ceb5458...  13722353
# 4999  0x3968866d18638ab6e036c94062fb7226140ea00b7ba2...  13722355
#
#       UnixTimestamp             DateTime  \
# 0        1638316845  2021-12-01 00:00:45
# 1        1638316845  2021-12-01 00:00:45
# 2        1638316877  2021-12-01 00:01:17
# ...

# %%
ax = sns.kdeplot(data=sushiswap, y="TxnFee(USD)", shade=True, vertical=True)
ax.set(xlim=(0, 200))
plt.title("Sushiswap: Kernel Density Estimate Plot");

# %%
curve = pd.read_csv('curve.csv', index_col=False)
curve
# Out:
#                                                 Txhash   Blockno  \
# 0    0xbdb2c97f93d27504f2a79af64b22b2d1c3dca8f485b1...  13717847
# 1    0xdac78465b3600c61676b994f94a84ee8ded5eb9f5313...  13717850
# 2    0x1ccf904bd97834f5189440353274c8bae526134ce84a...  13717880
# 3    0x661bf971f081e548c4ab8cb645ef4d4d70f31d94fc29...  13717881
# 4    0xa42415d235557783553ef47199241417fbe3cacdbe6e...  13717917
# ..                                                 ...       ...
# 146  0x82d2e3c8d43c71d8d710f6e4f124d800d5bbd734c8d4...  13730022
# 147  0x7f5ea39b9a3575b4229bb3f1f3ea53da7a4438e01563...  13730023
# 148  0xed6bcfa1c1285cd29aca0705697b9d5a56474c023e04...  13730156
# 149  0x2ae977359dd2d18a371e86b5a3a31d5cbf49c6d36a2c...  13730213
# 150  0x9b18d6eb16ad84adc23bca738fd474154e0bec3e0df7...  13730217
#
#      UnixTimestamp             DateTime  \
# 0       1638316845  2021-12-01 00:00:45
# 1       1638316917  2021-12-01 00:01:57
# 2       1638317422  2021-12-01 00:10:22
# ...

# %%
ax = sns.kdeplot(data=curve, y="TxnFee(USD)", shade=True, vertical=True)
ax.set(xlim=(0, 200))
plt.title("Curve: Kernel Density Estimate Plot");
