# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Default plot configurations
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

import warnings
warnings.filterwarnings("ignore")

from IPython.display import display, Latex, Markdown

# get data from csv
curvedata, uniswap, sushiswap = "curvedata", "uniswap", "sushiswap"
curvedata = pd.read_csv(f'etherscan-{curvedata}.csv')
uniswap = pd.read_csv(f'etherscan-{uniswap}data.csv')
sushiswap = pd.read_csv(f'etherscan-{sushiswap}data.csv')
curvedata
# Out:
#                                                       Txhash     Blockno  \
# 0xdfdf60f8818c2170a429ac01f33b9bf0fd9fb88a7559d...  13717922  1638318159
# 0x334388a34b63e03e9e30fb4b6844aebf2f58d45d18eae...  13718135  1638321122
# 0x1abf97cb3ad351a30c29b263d38361cd9a44683350c1c...  13718461  1638325475
# 0x5c1c4b8cd21c5e64f248ed6435edc8b5b60c770a745c6...  13718512  1638326280
# 0x9c66ccb476f0bce7aea4e6b50cf0ae4a2b767ec6b90fd...  13718825  1638330567
# ...                                                      ...         ...
# 0x545b38f8ba16e9176a0b2c985dfc2488d8247667862ae...  13729055  1638471890
# 0xb90a62977888662ad6c751112160545121d0cf91e4122...  13729060  1638471941
# 0xe6c632b9b7ad9c55c578daa7ea0a32c470ff41233cde7...  13729060  1638471941
# 0x7bab216f520ee2e6217a4f299ff46f1a9c9a234ad2a37...  13729111  1638472630
# 0x1ecf9f51539ab813675195112c06da5460cb7491b47ec...  13729227  1638474194
#
#                                                           UnixTimestamp  \
# ...

# %%
uniswap
# Out:
#                                                       Txhash     Blockno  \
# 0xa761f3c7cd9d32325ca2d2ce8682a70f3bba939cbfcc4...  13717847  1638316845
# 0x522ca51c4e1ab6a62a374646618597935187a79ce44cb...  13717847  1638316845
# 0x548160f1141f451a065b6f98d4db5ed6f8fb23d918fe4...  13717847  1638316845
# 0x0a04b38bf7bfb7ad4fa44a1460e718c1039a587984628...  13717847  1638316845
# 0x4a4018e74f77af78c9320cbbc02ed804d30638f16c332...  13717847  1638316845
# ...                                                      ...         ...
# 0x959e3538b1f6ac3b68bd5ae862e97915b36ad41a36f3c...  13719430  1638338592
# 0x2af717f2488023a66777afbdd567ef6da2e1c1d4148d1...  13719430  1638338592
# 0xf286731baa778fc67ffef73235d32827a4ebf3f007dec...  13719430  1638338592
# 0x745ffe95a0956c5b39d89347c343860fcbc5c76e94415...  13719430  1638338592
# 0x96cb40f5861a561f773d78bfe314cfbf67a398839d016...  13719430  1638338592
#
#                                                           UnixTimestamp  \
# ...

# %%
sushiswap
# Out:
#                                                       Txhash     Blockno  \
# 0xee18f6342683fdf60bbb57abc1f00e607ed034427a722...  13717847  1638316845
# 0x51677a40b48456b15cce7e399c69d169c7a032beb951e...  13717847  1638316845
# 0xff0d2e021d59bb7d471ee3e3ecddd5ef679c4b7433f0a...  13717849  1638316877
# 0x0844b05ef2d68f509e495d2564ecba8f9eec1c7feb038...  13717849  1638316877
# 0xd086dc6c6990016b8bfbb2959bade7c4b15e1feaf5476...  13717849  1638316877
# ...                                                      ...         ...
# 0xf560b03021ab34c9a6b58cf059cf2a1c1dc8c8599f73e...  13722350  1638379564
# 0xdd188fab54b97a6777ead3af9a084fd4e4dd1cbb167f8...  13722351  1638379572
# 0x21cb9f6a22f585dcaf506997367b409c4025e34b30e5d...  13722352  1638379649
# 0xf2246d0a9fac22b184e9cc2678facdc069e24ceb5458f...  13722353  1638379699
# 0x3968866d18638ab6e036c94062fb7226140ea00b7ba2d...  13722355  1638379723
#
#                                                           UnixTimestamp  \
# ...

# %%
tbl = curvedata.rename({"TxnFee(ETH)":"curvedata TxnFee(ETH)"})
sns.lineplot(x=tbl['DateTime'], y=tbl["TxnFee(ETH)"], label="curvedata TxnFee(ETH)")

tbl = uniswap.rename({"TxnFee(ETH)":"uniswap TxnFee(ETH)"})
sns.lineplot(x=tbl['DateTime'], y=tbl["TxnFee(ETH)"], label="uniswap TxnFee(ETH)")

tbl = sushiswap.rename({"TxnFee(ETH)":"sushiswap TxnFee(ETH)"})
sns.lineplot(x=tbl['DateTime'], y=tbl["TxnFee(ETH)"], label="sushiswap TxnFee(ETH)")

plt.legend(loc='upper left')
plt.xlabel("DateTime")
plt.ylabel("TxnFee (ETH)")
plt.title("TxnFee(ETH) vs DateTime");
# Out:
# Error in callback <function flush_figures at 0x11d8408b0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     117         # ignore the tracking, just draw and close all figures
#     118         try:
# --> 119             return show(True)
#     120         except Exception as e:
#     121             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37     try:
#      38         for figure_manager in Gcf.get_all_fig_managers():
# ---> 39             display(
#      40                 figure_manager.canvas.figure,
#      41                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
tbl = curvedata
sns.lineplot(x=tbl['DateTime'], y=tbl["TxnFee(ETH)"], label="TxnFee(ETH)")
plt.legend(loc='upper left')
plt.xlabel("DateTime")
plt.ylabel("TxnFee (ETH)")
plt.title("TxnFee(ETH) vs DateTime");

# %%
# outlier detection

# %%
label = "TxnFee(ETH)"
cd_label = f"curvedata {label}"
tbl = curvedata.rename({label:cd_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=cd_label)

us_label = f"uniswap {label}"
tbl = uniswap.rename({label:us_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=us_label)

ss_label = f"sushiswap {label}"
tbl = sushiswap.rename({label:ss_label})
sns.lineplot(x=tbl['DateTime'], y=tbl[label], label=ss_label)

plt.legend(loc='upper left')
x = "DateTime"
plt.xlabel(x)
plt.ylabel(label)
plt.title(f"{label} vs {x}");

# %%
filename = 'data.txt'
data = open(filename).read().splitlines()
# print(data)
n = 1000
assert n == len(data), "error reading all data"
split_point = n >> 1
spent, received = np.array(data[::2]), np.array(data[1::2])
# print(spent, received, sep="\n"*3)
spent, received = spent.astype(np.float), received.astype(np.float)
total_ETH_spent = np.cumsum(spent)
ETH = 1e18
total_ETH_spent /= ETH
WBTC = 1e8
received /= WBTC
received **= 2

print(total_ETH_spent, received,sep='\n'*3)
# Out:
# [1.00000000e-02 3.01500000e-02 6.06022500e-02 1.01511284e-01
#  1.53033953e-01 2.15329462e-01 2.88559404e-01 3.72887795e-01
#  4.68481112e-01 5.75508329e-01 6.94140954e-01 8.24553068e-01
#  9.66921364e-01 1.12142518e+00 1.28824656e+00 1.46757026e+00
#  1.65958381e+00 1.86447757e+00 2.08244474e+00 2.31368141e+00
#  2.55838663e+00 2.81676243e+00 3.08901386e+00 3.37534907e+00
#  3.67597931e+00 3.99111900e+00 4.32098578e+00 4.66580057e+00
#  5.02578758e+00 5.40117439e+00 5.79219201e+00 6.19907489e+00
#  6.62206101e+00 7.06139193e+00 7.51731280e+00 7.99007250e+00
#  8.47992358e+00 8.98712244e+00 9.51192927e+00 1.00546082e+01
#  1.06154273e+01 1.11946587e+01 1.17925786e+01 1.24094673e+01
#  1.30456093e+01 1.37012935e+01 1.43768129e+01 1.50724651e+01
#  1.57885520e+01 1.65253803e+01 1.72832610e+01 1.80625099e+01
#  1.88634476e+01 1.96863993e+01 2.05316953e+01 2.13996707e+01
#  2.22906658e+01 2.32050258e+01 2.41431011e+01 2.51052477e+01
# ...

# %%
sns.lineplot(total_ETH_spent, received)
x, y = "Total ETH Spent", "Received"
plt.xlabel(x)
plt.ylabel(y)
plt.title(f"{y} vs {x}");
